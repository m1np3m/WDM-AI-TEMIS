# %%
# Thay thế tất cả các cell !pip install bằng cell duy nhất này
# !pip install llama-index-graph-stores-neo4j llama-index-vector-stores-chroma llama-index-embeddings-huggingface llama-index-llms-openrouter python-dotenv sentence-transformers
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: llama-index-graph-stores-neo4j in /home/tiamo/.local/lib/python3.10/site-packages (0.4.6)
# Requirement already satisfied: llama-index-vector-stores-chroma in /home/tiamo/.local/lib/python3.10/site-packages (0.4.2)
# Requirement already satisfied: llama-index-embeddings-huggingface in /home/tiamo/.local/lib/python3.10/site-packages (0.5.4)
# Requirement already satisfied: llama-index-llms-openrouter in /home/tiamo/.local/lib/python3.10/site-packages (0.3.2)
# Requirement already satisfied: python-dotenv in /home/tiamo/.local/lib/python3.10/site-packages (1.0.1)
# Requirement already satisfied: sentence-transformers in /home/tiamo/.local/lib/python3.10/site-packages (4.1.0)
# Requirement already satisfied: llama-index-core<0.13.0,>=0.12.0 in /home/tiamo/.local/lib/python3.10/site-packages (from llama-index-graph-stores-neo4j) (0.12.43)
# Requirement already satisfied: neo4j<6.0.0,>=5.16.0 in /home/tiamo/.local/lib/python3.10/site-packages (from llama-index-graph-stores-neo4j) (5.28.1)
# Requirement already satisfied: aiohttp<4,>=3.8.6 in /home/tiamo/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (3.11.18)
# Requirement already satisfied: aiosqlite in /home/tiamo/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (0.21.0)
# Requirement already satisfied: banks<3,>=2.0.0 in /home/tiamo/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (2.1.2)
# Requirement already satisfied: dataclasses-json in /home/tiamo/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /home/tiamo/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (1.2.18)
# Requirement already satisfied: dirtyjson<2,>=1.0.8 in /home/tiamo/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (1.0.8)
# Requirement already satisfied: filetype<2,>=1.2.0 in /home/tiamo/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/tiamo/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (2024.12.0)
# Requirement already satisfied: httpx in /home/tiamo/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (0.27.0)
# Requirement already satisfied: llama-index-workflows>=0.2.1 in /home/tiamo/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (0.2.2)
# Requirement already satisfied: nest-asyncio<2,>=1.5.8 in /home/tiamo/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /home/tiamo/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (3.3)
# Requirement already satisfied: nltk>3.8.1 in /home/tiamo/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (3.9.1)
# Requirement already satisfied: numpy in /home/tiamo/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in /home/tiamo/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (10.4.0)
# Requirement already satisfied: pydantic>=2.8.0 in /home/tiamo/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (2.11.7)
# Requirement already satisfied: pyyaml>=6.0.1 in /home/tiamo/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (6.0.2)
# Requirement already satisfied: requests>=2.31.0 in /home/tiamo/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (2.32.3)
# Requirement already satisfied: setuptools>=80.9.0 in /home/tiamo/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (80.9.0)
# Requirement already satisfied: sqlalchemy>=1.4.49 in /home/tiamo/.local/lib/python3.10/site-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (2.0.29)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in /home/tiamo/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (8.2.3)
# Requirement already satisfied: tiktoken>=0.7.0 in /home/tiamo/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (0.9.0)
# Requirement already satisfied: tqdm<5,>=4.66.1 in /home/tiamo/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /home/tiamo/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in /home/tiamo/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (0.9.0)
# Requirement already satisfied: wrapt in /home/tiamo/.local/lib/python3.10/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (1.16.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/tiamo/.local/lib/python3.10/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/tiamo/.local/lib/python3.10/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /home/tiamo/.local/lib/python3.10/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /home/tiamo/.local/lib/python3.10/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/tiamo/.local/lib/python3.10/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/tiamo/.local/lib/python3.10/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /home/tiamo/.local/lib/python3.10/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/tiamo/.local/lib/python3.10/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (1.20.0)
# Requirement already satisfied: griffe in /home/tiamo/.local/lib/python3.10/site-packages (from banks<3,>=2.0.0->llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (1.7.3)
# Requirement already satisfied: jinja2 in /home/tiamo/.local/lib/python3.10/site-packages (from banks<3,>=2.0.0->llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (3.1.3)
# Requirement already satisfied: platformdirs in /home/tiamo/.local/lib/python3.10/site-packages (from banks<3,>=2.0.0->llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (4.3.8)
# Requirement already satisfied: pytz in /usr/lib/python3/dist-packages (from neo4j<6.0.0,>=5.16.0->llama-index-graph-stores-neo4j) (2022.1)
# Requirement already satisfied: idna>=2.0 in /usr/lib/python3/dist-packages (from yarl<2.0,>=1.17.0->aiohttp<4,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (3.3)
# Requirement already satisfied: chromadb>=0.5.17 in /home/tiamo/.local/lib/python3.10/site-packages (from llama-index-vector-stores-chroma) (1.0.13)
# Requirement already satisfied: huggingface-hub>=0.19.0 in /home/tiamo/.local/lib/python3.10/site-packages (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (0.31.1)
# Requirement already satisfied: llama-index-llms-openai-like<0.5,>=0.4.0 in /home/tiamo/.local/lib/python3.10/site-packages (from llama-index-llms-openrouter) (0.4.0)
# Requirement already satisfied: llama-index-llms-openai<0.5,>=0.4.0 in /home/tiamo/.local/lib/python3.10/site-packages (from llama-index-llms-openai-like<0.5,>=0.4.0->llama-index-llms-openrouter) (0.4.7)
# Requirement already satisfied: transformers<5,>=4.37.0 in /home/tiamo/.local/lib/python3.10/site-packages (from llama-index-llms-openai-like<0.5,>=0.4.0->llama-index-llms-openrouter) (4.42.4)
# Requirement already satisfied: openai<2,>=1.81.0 in /home/tiamo/.local/lib/python3.10/site-packages (from llama-index-llms-openai<0.5,>=0.4.0->llama-index-llms-openai-like<0.5,>=0.4.0->llama-index-llms-openrouter) (1.82.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/tiamo/.local/lib/python3.10/site-packages (from openai<2,>=1.81.0->llama-index-llms-openai<0.5,>=0.4.0->llama-index-llms-openai-like<0.5,>=0.4.0->llama-index-llms-openrouter) (4.3.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai<2,>=1.81.0->llama-index-llms-openai<0.5,>=0.4.0->llama-index-llms-openai-like<0.5,>=0.4.0->llama-index-llms-openrouter) (1.7.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /home/tiamo/.local/lib/python3.10/site-packages (from openai<2,>=1.81.0->llama-index-llms-openai<0.5,>=0.4.0->llama-index-llms-openai-like<0.5,>=0.4.0->llama-index-llms-openrouter) (0.10.0)
# Requirement already satisfied: sniffio in /home/tiamo/.local/lib/python3.10/site-packages (from openai<2,>=1.81.0->llama-index-llms-openai<0.5,>=0.4.0->llama-index-llms-openai-like<0.5,>=0.4.0->llama-index-llms-openrouter) (1.3.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/tiamo/.local/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai<2,>=1.81.0->llama-index-llms-openai<0.5,>=0.4.0->llama-index-llms-openai-like<0.5,>=0.4.0->llama-index-llms-openrouter) (1.2.0)
# Requirement already satisfied: certifi in /home/tiamo/.local/lib/python3.10/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (2025.6.15)
# Requirement already satisfied: httpcore==1.* in /home/tiamo/.local/lib/python3.10/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (1.0.4)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/tiamo/.local/lib/python3.10/site-packages (from httpcore==1.*->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/tiamo/.local/lib/python3.10/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /home/tiamo/.local/lib/python3.10/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/tiamo/.local/lib/python3.10/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (0.4.1)
# Requirement already satisfied: filelock in /home/tiamo/.local/lib/python3.10/site-packages (from transformers<5,>=4.37.0->llama-index-llms-openai-like<0.5,>=0.4.0->llama-index-llms-openrouter) (3.15.4)
# Requirement already satisfied: packaging>=20.0 in /home/tiamo/.local/lib/python3.10/site-packages (from transformers<5,>=4.37.0->llama-index-llms-openai-like<0.5,>=0.4.0->llama-index-llms-openrouter) (23.2)
# Requirement already satisfied: regex!=2019.12.17 in /home/tiamo/.local/lib/python3.10/site-packages (from transformers<5,>=4.37.0->llama-index-llms-openai-like<0.5,>=0.4.0->llama-index-llms-openrouter) (2024.5.15)
# Requirement already satisfied: safetensors>=0.4.1 in /home/tiamo/.local/lib/python3.10/site-packages (from transformers<5,>=4.37.0->llama-index-llms-openai-like<0.5,>=0.4.0->llama-index-llms-openrouter) (0.4.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /home/tiamo/.local/lib/python3.10/site-packages (from transformers<5,>=4.37.0->llama-index-llms-openai-like<0.5,>=0.4.0->llama-index-llms-openrouter) (0.19.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.0 in /home/tiamo/.local/lib/python3.10/site-packages (from huggingface-hub>=0.19.0->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface) (1.1.0)
# Requirement already satisfied: torch>=1.11.0 in /home/tiamo/.local/lib/python3.10/site-packages (from sentence-transformers) (2.3.1)
# Requirement already satisfied: scikit-learn in /home/tiamo/.local/lib/python3.10/site-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy in /home/tiamo/.local/lib/python3.10/site-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: build>=1.0.3 in /home/tiamo/.local/lib/python3.10/site-packages (from chromadb>=0.5.17->llama-index-vector-stores-chroma) (1.2.2.post1)
# Requirement already satisfied: pybase64>=1.4.1 in /home/tiamo/.local/lib/python3.10/site-packages (from chromadb>=0.5.17->llama-index-vector-stores-chroma) (1.4.1)
# Requirement already satisfied: uvicorn>=0.18.3 in /home/tiamo/.local/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.17->llama-index-vector-stores-chroma) (0.34.3)
# Requirement already satisfied: posthog>=2.4.0 in /home/tiamo/.local/lib/python3.10/site-packages (from chromadb>=0.5.17->llama-index-vector-stores-chroma) (5.4.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /home/tiamo/.local/lib/python3.10/site-packages (from chromadb>=0.5.17->llama-index-vector-stores-chroma) (1.22.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /home/tiamo/.local/lib/python3.10/site-packages (from chromadb>=0.5.17->llama-index-vector-stores-chroma) (1.34.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /home/tiamo/.local/lib/python3.10/site-packages (from chromadb>=0.5.17->llama-index-vector-stores-chroma) (1.34.1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /home/tiamo/.local/lib/python3.10/site-packages (from chromadb>=0.5.17->llama-index-vector-stores-chroma) (1.34.1)
# Requirement already satisfied: pypika>=0.48.9 in /home/tiamo/.local/lib/python3.10/site-packages (from chromadb>=0.5.17->llama-index-vector-stores-chroma) (0.48.9)
# Requirement already satisfied: overrides>=7.3.1 in /home/tiamo/.local/lib/python3.10/site-packages (from chromadb>=0.5.17->llama-index-vector-stores-chroma) (7.7.0)
# Requirement already satisfied: importlib-resources in /home/tiamo/.local/lib/python3.10/site-packages (from chromadb>=0.5.17->llama-index-vector-stores-chroma) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /home/tiamo/.local/lib/python3.10/site-packages (from chromadb>=0.5.17->llama-index-vector-stores-chroma) (1.73.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /home/tiamo/.local/lib/python3.10/site-packages (from chromadb>=0.5.17->llama-index-vector-stores-chroma) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in /home/tiamo/.local/lib/python3.10/site-packages (from chromadb>=0.5.17->llama-index-vector-stores-chroma) (0.16.0)
# Requirement already satisfied: kubernetes>=28.1.0 in /home/tiamo/.local/lib/python3.10/site-packages (from chromadb>=0.5.17->llama-index-vector-stores-chroma) (33.1.0)
# Requirement already satisfied: mmh3>=4.0.1 in /home/tiamo/.local/lib/python3.10/site-packages (from chromadb>=0.5.17->llama-index-vector-stores-chroma) (5.1.0)
# Requirement already satisfied: orjson>=3.9.12 in /home/tiamo/.local/lib/python3.10/site-packages (from chromadb>=0.5.17->llama-index-vector-stores-chroma) (3.10.18)
# Requirement already satisfied: rich>=10.11.0 in /home/tiamo/.local/lib/python3.10/site-packages (from chromadb>=0.5.17->llama-index-vector-stores-chroma) (13.7.1)
# Requirement already satisfied: jsonschema>=4.19.0 in /home/tiamo/.local/lib/python3.10/site-packages (from chromadb>=0.5.17->llama-index-vector-stores-chroma) (4.21.1)
# Requirement already satisfied: pyproject_hooks in /home/tiamo/.local/lib/python3.10/site-packages (from build>=1.0.3->chromadb>=0.5.17->llama-index-vector-stores-chroma) (1.2.0)
# Requirement already satisfied: tomli>=1.1.0 in /home/tiamo/.local/lib/python3.10/site-packages (from build>=1.0.3->chromadb>=0.5.17->llama-index-vector-stores-chroma) (2.0.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/tiamo/.local/lib/python3.10/site-packages (from jsonschema>=4.19.0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/tiamo/.local/lib/python3.10/site-packages (from jsonschema>=4.19.0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (0.33.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/tiamo/.local/lib/python3.10/site-packages (from jsonschema>=4.19.0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (0.18.0)
# Requirement already satisfied: six>=1.9.0 in /usr/lib/python3/dist-packages (from kubernetes>=28.1.0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /home/tiamo/.local/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in /home/tiamo/.local/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (2.28.1)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /home/tiamo/.local/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (1.7.0)
# Requirement already satisfied: requests-oauthlib in /home/tiamo/.local/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /home/tiamo/.local/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (3.3.1)
# Requirement already satisfied: urllib3>=1.24.2 in /home/tiamo/.local/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (2.4.0)
# Requirement already satisfied: durationpy>=0.7 in /home/tiamo/.local/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (0.10)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/tiamo/.local/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/tiamo/.local/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/tiamo/.local/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in /home/tiamo/.local/lib/python3.10/site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (0.6.1)
# Requirement already satisfied: llama-index-instrumentation>=0.1.0 in /home/tiamo/.local/lib/python3.10/site-packages (from llama-index-workflows>=0.2.1->llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (0.2.0)
# Requirement already satisfied: click in /home/tiamo/.local/lib/python3.10/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (8.2.1)
# Requirement already satisfied: joblib in /home/tiamo/.local/lib/python3.10/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (1.3.2)
# Requirement already satisfied: coloredlogs in /home/tiamo/.local/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb>=0.5.17->llama-index-vector-stores-chroma) (15.0.1)
# Requirement already satisfied: flatbuffers in /home/tiamo/.local/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb>=0.5.17->llama-index-vector-stores-chroma) (24.3.25)
# Requirement already satisfied: protobuf in /home/tiamo/.local/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb>=0.5.17->llama-index-vector-stores-chroma) (5.29.5)
# Requirement already satisfied: sympy in /usr/lib/python3/dist-packages (from onnxruntime>=1.14.1->chromadb>=0.5.17->llama-index-vector-stores-chroma) (1.9)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /home/tiamo/.local/lib/python3.10/site-packages (from opentelemetry-api>=1.2.0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in /home/tiamo/.local/lib/python3.10/site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (3.23.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /home/tiamo/.local/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.34.1 in /home/tiamo/.local/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (1.34.1)
# Requirement already satisfied: opentelemetry-proto==1.34.1 in /home/tiamo/.local/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (1.34.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.55b1 in /home/tiamo/.local/lib/python3.10/site-packages (from opentelemetry-sdk>=1.2.0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (0.55b1)
# Requirement already satisfied: backoff>=1.10.0 in /home/tiamo/.local/lib/python3.10/site-packages (from posthog>=2.4.0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (2.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/tiamo/.local/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (3.3.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/tiamo/.local/lib/python3.10/site-packages (from rich>=10.11.0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/tiamo/.local/lib/python3.10/site-packages (from rich>=10.11.0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (2.17.2)
# Requirement already satisfied: mdurl~=0.1 in /home/tiamo/.local/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (0.1.2)
# Requirement already satisfied: greenlet!=0.4.17 in /home/tiamo/.local/lib/python3.10/site-packages (from sqlalchemy>=1.4.49->sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (3.2.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/tiamo/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/tiamo/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/tiamo/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/tiamo/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/tiamo/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/tiamo/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/tiamo/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/tiamo/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/tiamo/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/tiamo/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/tiamo/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (12.1.105)
# Requirement already satisfied: triton==2.3.1 in /home/tiamo/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (2.3.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/tiamo/.local/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.11.0->sentence-transformers) (12.5.82)
# Requirement already satisfied: shellingham>=1.3.0 in /home/tiamo/.local/lib/python3.10/site-packages (from typer>=0.9.0->chromadb>=0.5.17->llama-index-vector-stores-chroma) (1.5.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/tiamo/.local/lib/python3.10/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (1.1.0)
# Requirement already satisfied: httptools>=0.6.3 in /home/tiamo/.local/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.17->llama-index-vector-stores-chroma) (0.6.4)
# Requirement already satisfied: uvloop>=0.15.1 in /home/tiamo/.local/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.17->llama-index-vector-stores-chroma) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in /home/tiamo/.local/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.17->llama-index-vector-stores-chroma) (1.1.0)
# Requirement already satisfied: websockets>=10.4 in /home/tiamo/.local/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.17->llama-index-vector-stores-chroma) (13.1)
# Requirement already satisfied: humanfriendly>=9.1 in /home/tiamo/.local/lib/python3.10/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb>=0.5.17->llama-index-vector-stores-chroma) (10.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/tiamo/.local/lib/python3.10/site-packages (from dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (3.26.1)
# Requirement already satisfied: colorama>=0.4 in /usr/lib/python3/dist-packages (from griffe->banks<3,>=2.0.0->llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (0.4.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/tiamo/.local/lib/python3.10/site-packages (from jinja2->banks<3,>=2.0.0->llama-index-core<0.13.0,>=0.12.0->llama-index-graph-stores-neo4j) (2.1.5)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/tiamo/.local/lib/python3.10/site-packages (from scikit-learn->sentence-transformers) (3.4.0)

# %%
import os
import chromadb
from dotenv import load_dotenv
import logging

from llama_index.core import Document, VectorStoreIndex, Settings
from llama_index.graph_stores.neo4j import Neo4jGraphStore
from llama_index.vector_stores.chroma import ChromaVectorStore
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
from llama_index.llms.openrouter import OpenRouter 

logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
load_dotenv()


Settings.llm = OpenRouter(
    api_key=os.getenv("OPENAI_API_KEY"), 
    model="mistralai/mistral-7b-instruct:free",
    default_headers={
        "HTTP-Referer": os.getenv("YOUR_SITE_URL", "http://localhost:8888"), 
        "X-Title": os.getenv("YOUR_SITE_NAME", "VectorGraphRAG PoC"),     
    },
    max_tokens=512,
    temperature=0.1,
)
logging.info(f"✅ LLM đã được cấu hình để sử dụng model '{Settings.llm.model}' từ OpenRouter.")


# Cấu hình Embedding Model (giữ nguyên)
Settings.embed_model = HuggingFaceEmbedding(model_name="bkai-foundation-models/vietnamese-bi-encoder")

# --- 2. DỮ LIỆU MẪU (giữ nguyên) ---
text_docs = [
    Document(
        text="Triết lý thiết kế của Steve Jobs tại Apple luôn tập trung vào sự đơn giản, trực quan và đặt trải nghiệm người dùng làm trung tâm. Ông tin rằng sản phẩm không chỉ cần mạnh mẽ về chức năng mà còn phải là một tác phẩm nghệ thuật, đẹp từ trong ra ngoài. Điều này đã định hình nên các sản phẩm biểu tượng như iPhone và MacBook.",
        metadata={"source": "Phân tích nội bộ"}
    ),
    Document(
        text="iPhone 15, ra mắt năm 2023, tiếp tục kế thừa di sản thiết kế của Apple với khung viền titan, cổng USB-C và hệ thống camera cải tiến mạnh mẽ. Nó được xem là một trong những smartphone hàng đầu thị trường, thể hiện rõ triết lý của công ty.",
        metadata={"source": "Đánh giá sản phẩm TechReview"}
    ),
    Document(
        text="Cuộc đối đầu giữa Apple và Samsung là một trong những câu chuyện kinh điển của làng công nghệ. Trong khi Apple tập trung vào hệ sinh thái khép kín và sự tối ưu hóa phần cứng-phần mềm, Samsung lại đa dạng hóa sản phẩm với nhiều phân khúc và tiên phong trong các công nghệ màn hình gập.",
        metadata={"source": "Bài báo kinh doanh"}
    ),
]
graph_triplets = [
    ("Steve Jobs", "FOUNDED", "Apple"),
    ("Apple", "PRODUCES", "iPhone 15"),
    ("Apple", "HAS_PHILOSOPHY", "Thiết kế tối giản và trải nghiệm người dùng"),
    ("Samsung", "PRODUCES", "Galaxy S24"),
    ("Samsung", "COMPETES_WITH", "Apple")
]

# --- 3. INGESTION VÀO NEO4J (GraphDB) (giữ nguyên) ---
logging.info("--- Bắt đầu Ingest vào Neo4j ---")
graph_store = Neo4jGraphStore(
    username=os.getenv("NEO4J_USERNAME"),
    password=os.getenv("NEO4J_PASSWORD"),
    url=os.getenv("NEO4J_URI"),
    database="neo4j",
    refresh_schema=False
)
graph_store.query("MATCH (n) DETACH DELETE n")
for subj, pred, obj in graph_triplets:
    graph_store.upsert_triplet(subj, pred, obj)
logging.info("--- Ingest vào Neo4j Hoàn tất ---")


# --- 4. INGESTION VÀO CHROMADB (VectorDB) (giữ nguyên) ---
logging.info("--- Bắt đầu Ingest vào ChromaDB ---")
db = chromadb.PersistentClient(path="./chroma_db")
chroma_collection = db.get_or_create_collection("vector_graph_rag_poc")
vector_store = ChromaVectorStore(chroma_collection=chroma_collection)
vector_index = VectorStoreIndex.from_documents(
    text_docs, vector_store=vector_store
)
logging.info("--- Ingest vào ChromaDB Hoàn tất ---")
# Out:
# 2025-06-30 10:33:26,738 - INFO - ✅ LLM đã được cấu hình để sử dụng model 'mistralai/mistral-7b-instruct:free' từ OpenRouter.
# 2025-06-30 10:33:26,741 - INFO - Load pretrained SentenceTransformer: bkai-foundation-models/vietnamese-bi-encoder
# 2025-06-30 10:33:30,988 - INFO - 2 prompts are loaded, with the keys: ['query', 'text']
# 2025-06-30 10:33:30,989 - INFO - --- Bắt đầu Ingest vào Neo4j ---
# 2025-06-30 10:33:31,031 - INFO - Received notification from DBMS server: {severity: INFORMATION} {code: Neo.ClientNotification.Schema.IndexOrConstraintAlreadyExists} {category: SCHEMA} {title: `CREATE CONSTRAINT IF NOT EXISTS FOR (e:Entity) REQUIRE (e.id) IS UNIQUE` has no effect.} {description: `CONSTRAINT constraint_1ed05907 FOR (e:Entity) REQUIRE (e.id) IS UNIQUE` already exists.} {position: None} for query: '\n                CREATE CONSTRAINT IF NOT EXISTS FOR (n:Entity) REQUIRE n.id IS UNIQUE;\n                '
# 2025-06-30 10:33:31,141 - INFO - --- Ingest vào Neo4j Hoàn tất ---
# 2025-06-30 10:33:31,141 - INFO - --- Bắt đầu Ingest vào ChromaDB ---
# 2025-06-30 10:33:31,558 - INFO - --- Ingest vào ChromaDB Hoàn tất ---

# %%
import json
from llama_index.core.llms import ChatMessage

def transform_query(query: str) -> dict:
    """
    Sử dụng LLM để phân rã câu hỏi phức tạp.
    """
    prompt = f"""
Bạn là một trợ lý AI hữu ích, chuyên phân tích và phân rã các câu hỏi phức tạp của người dùng thành các nhiệm vụ con cho một hệ thống RAG. Mục tiêu của bạn là tách câu hỏi gốc thành một danh sách các câu hỏi con độc lập và trích xuất các thực thể chính. Một số câu hỏi con sẽ được dùng để truy vấn cơ sở dữ liệu vector (để lấy thông tin mô tả), và các thực thể sẽ được dùng để truy vấn đồ thị tri thức (để lấy dữ liệu thực tế và các mối quan hệ).

Dựa trên câu hỏi của người dùng, hãy tạo một đối tượng JSON chứa hai danh sách: 'vector_search_queries' và 'graph_entities'.

- 'vector_search_queries': Chứa các câu hỏi mô tả, đầy đủ ý nghĩa.
- 'graph_entities': Chứa các thực thể chính được xác định trong câu hỏi.

User Question: "{query}"

{{
  "vector_search_queries": [],
  "graph_entities": []
}}
"""
    response = Settings.llm.chat([ChatMessage(role="user", content=prompt)])
    try:
        # Cố gắng trích xuất JSON nếu nó nằm trong khối markdown
        json_match = re.search(r"```json\n(.*?)\n```", content, re.S)
        if json_match:
            content = json_match.group(1)

        result = json.loads(content)
        return result
    except (json.JSONDecodeError, TypeError) as e:
        # Fallback nếu LLM không trả về JSON hợp lệ
        logging.error(f"Lỗi khi phân tích JSON từ LLM: {e}")
        logging.error(f"Nội dung nhận được từ LLM: '{content}'")
        logging.info("Sử dụng fallback: trả về câu hỏi gốc làm truy vấn vector.")
        return {"vector_search_queries": [query], "graph_entities": []}

# %%
import asyncio
from llama_index.core.postprocessor.types import BaseNodePostprocessor
from llama_index.core.schema import NodeWithScore, QueryBundle
from typing import List, Optional
import re

# Lấy lại graph_store đã khởi tạo ở bước trước
graph_store = Neo4jGraphStore(
    username=os.getenv("NEO4J_USERNAME"),
    password=os.getenv("NEO4J_PASSWORD"),
    url=os.getenv("NEO4J_URI"),
    database="neo4j",
    refresh_schema=False
)

def get_connected_entities(entity: str) -> List[str]:
    """Truy vấn Neo4j để tìm các thực thể có kết nối trực tiếp."""
    try:
        query = f"""
        MATCH (e1 {{id: "{entity}"}})-- (e2)
        RETURN e2.id
        """
        result = graph_store.query(query)
        return [item['e2.id'] for item in result] if result else []
    except:
        return []

class GraphSignalBooster(BaseNodePostprocessor):
    """
    Tăng điểm cho các node dựa trên tín hiệu từ đồ thị tri thức.
    """
    # BƯỚC 1: Khai báo các thuộc tính của lớp trước
    graph_entities: List[str] = []
    weight: float = 1.5
    
    # BƯỚC 2: Khai báo một thuộc tính riêng tư để lưu các thực thể liên quan
    # Chúng ta dùng _related_entities để tránh xung đột với Pydantic
    _related_entities: set = set()

    # BƯỚC 3: Sửa lại hàm __init__
    def __init__(
        self,
        graph_entities: List[str],
        weight: float = 1.5,
        **kwargs
    ):
        # Gọi super().__init__ và truyền các giá trị vào
        # Pydantic sẽ tự động gán self.graph_entities và self.weight
        super().__init__(graph_entities=graph_entities, weight=weight, **kwargs)
        
        # Bây giờ, chúng ta có thể thực hiện logic tính toán
        self._related_entities = set(self.graph_entities)
        for entity in self.graph_entities:
            connected = get_connected_entities(entity)
            self._related_entities.update(connected)
        print(f"[GraphSignalBooster] Các thực thể liên quan từ đồ thị: {self._related_entities}")

    def _postprocess_nodes(
        self, nodes: List[NodeWithScore], query_bundle: Optional[QueryBundle] = None
    ) -> List[NodeWithScore]:
        # BƯỚC 4: Sử dụng _related_entities thay vì self.related_entities
        boosted_nodes = []
        for node_with_score in nodes:
            node_text = node_with_score.node.get_content().lower()
            boost_factor = 1.0
            
            found_entities = []
            for entity in self._related_entities: # <-- SỬA Ở ĐÂY
                if re.search(r'\\b' + re.escape(entity.lower()) + r'\\b', node_text):
                    # Sử dụng self.weight đã được Pydantic gán
                    boost_factor = self.weight
                    found_entities.append(entity)
            
            if boost_factor > 1.0:
                print(f"[GraphSignalBooster] Tăng điểm cho node (source: {node_with_score.node.metadata.get('source')}) vì chứa các thực thể liên quan: {found_entities}")

            node_with_score.score *= boost_factor
            boosted_nodes.append(node_with_score)
        
        boosted_nodes.sort(key=lambda x: x.score, reverse=True)
        return boosted_nodes
# Out:
# 2025-06-30 10:38:56,430 - INFO - Received notification from DBMS server: {severity: INFORMATION} {code: Neo.ClientNotification.Schema.IndexOrConstraintAlreadyExists} {category: SCHEMA} {title: `CREATE CONSTRAINT IF NOT EXISTS FOR (e:Entity) REQUIRE (e.id) IS UNIQUE` has no effect.} {description: `CONSTRAINT constraint_1ed05907 FOR (e:Entity) REQUIRE (e.id) IS UNIQUE` already exists.} {position: None} for query: '\n                CREATE CONSTRAINT IF NOT EXISTS FOR (n:Entity) REQUIRE n.id IS UNIQUE;\n                '

# %%
import asyncio
from llama_index.core.retrievers import VectorIndexRetriever
from llama_index.core import get_response_synthesizer
from llama_index.core.query_engine import RetrieverQueryEngine
# from llama_index.postprocessor.sentence_transformer_rerank import SentenceTransformerRerank
from llama_index.core.postprocessor import SentenceTransformerRerank

async def retrieve_from_vector_db(retriver, queries: List[str]) -> List[NodeWithScore]:
    tasks = [retriver.aretrieve(q) for q in queries]
    nested_results = await asyncio.gather(*tasks)
    
    all_nodes = [node for result in nested_results for node in result]
    
    for query, result in zip(queries, nested_results):
        print(f" Kết quả từ VectorDB cho {query}, được tìm thấy trong {len(result)} tài liệu")
        
    return all_nodes 

async def retrieve_from_graph_db(graph_store,entities: List[str]) -> List[Document]:
    async def query_entity(entity):
        cypher_query = f"MATCH (n {{id:'{entity}'}})-[r]-(m) RETURN n.id"
        try:
            graph_results = await asyncio.to_thread(graph_store.query,cypher_query)
            
            if graph_results:
                print(f"  > Kết quả từ GraphDB cho '{entity}': Đã tìm thấy {len(graph_results)} mối quan hệ.")
                text_result = f"Thông tin từ đồ thị về '{entity}':\n" + "\n".join([f"- {res['n.id']} {res['type(r)']} {res['m.id']}" for res in graph_results])
                return Document(text=text_result, metadata={"source": "GraphDB"})
            return None
        except Exception as e:
            print(f"  > Lỗi khi truy vấn GraphDB cho '{entity}': {e}")
            return None

    tasks = [query_entity(entity) for entity in entities]
    results = await asyncio.gather(*tasks)
    # Lọc ra những kết quả không phải None
    return [doc for doc in results if doc is not None]

async def run_hybrid_rag_pipeline(user_query:str):
    
    # Query Transform
    transformed = transform_query(user_query)
    vector_queries = transformed.get('vector_search_queries',[user_query])
    graph_entities = transformed.get('graph_entities',[])
    
    print(f"Vector Queries: {vector_queries}")
    print(f"Graph Entities: {graph_entities}")
    
    # Paralle Retrieval
    vector_retriever = VectorIndexRetriever(index=vector_index,similarity_top_k=5)
    
    vector_task = retrieve_from_vector_db(vector_retriever,vector_queries)
    graph_task = retrieve_from_graph_db(graph_store,graph_entities)
    
    all_retrieved_nodes, graph_retrieved_text = await asyncio.gather(vector_task,graph_task)
    
    # Combine Results
    unique_nodes = {node.get_content(): node for node in all_retrieved_nodes}
    combined_nodes = list(unique_nodes.values())
    
    for doc in graph_retrieved_text:
        combined_nodes.append(doc)
        
    # Reranking 
    reranker = SentenceTransformerRerank(model="BAAI/bge-reranker-v2-m3",top_n=5)
    graph_booster = GraphSignalBooster(graph_entities=graph_entities)
    
    response_synthesizer = get_response_synthesizer(
        response_mode="compact"
    )
    
    dummy_retriever = VectorIndexRetriever(index=vector_index,similarity_top_k=1)
    
    query_engine = RetrieverQueryEngine.from_args(
        retriever=dummy_retriever,
        response_synthesizer=response_synthesizer,
        node_postprocessor=[reranker,graph_booster]
    )
    
    if hasattr(query_engine, 'asynthesize'):
        final_response = await query_engine.asynthesize(
            query_bundle=QueryBundle(user_query),
            nodes=combined_nodes,
        )
    else: # Fallback cho phiên bản cũ hơn
         final_response = query_engine.synthesize(
            query_bundle=QueryBundle(user_query),
            nodes=combined_nodes,
        )
         
    print(f"Final Response: {final_response}")
    
    
    print("\n--- Các nguồn đã sử dụng để tạo câu trả lời: ---")
    for node in final_response.source_nodes:
        print(f"- Điểm: {node.score:.4f} | Nguồn: {node.metadata.get('source', 'N/A')}")
        print(f"  Nội dung: {node.get_content().strip()[:150]}...")

# %%
# complex_query = "Phân tích triết lý thiết kế của Steve Jobs và nó ảnh hưởng đến iPhone 15 như thế nào, một sản phẩm cạnh tranh với Samsung?"
# await run_hybrid_rag_pipeline(complex_query)
